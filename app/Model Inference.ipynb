# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
### Get the prediction map
class_map = {'Apple_Green': 0, 'Apple_Red': 1, 'Apple_Yellow': 2, 'Guava_Green': 3, 'Guava_Red': 4, 'Guava_Yellow': 5, 'Mandarine_Green': 6, 'Mandarine_Red': 7, 'Mandarine_Yellow': 8, 'Orange_Green': 9, 'Orange_Red': 10, 'Orange_Yellow': 11}
print(class_map)
# Out:
# {'Apple_Green': 0, 'Apple_Red': 1, 'Apple_Yellow': 2, 'Guava_Green': 3, 'Guava_Red': 4, 'Guava_Yellow': 5, 'Mandarine_Green': 6, 'Mandarine_Red': 7, 'Mandarine_Yellow': 8, 'Orange_Green': 9, 'Orange_Red': 10, 'Orange_Yellow': 11}

# %%
#Load Model
model = tf.keras.models.load_model("best_model.h5")

# %%
img = cv2.imread('../FruitData/SyntheticData/Test_Data/Apple_Yellow/3_100.jpg')
# Convert the image from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (256, 256))
plt.imshow(img)
plt.show()
img = img / 255.0
img = np.expand_dims(img, axis=0)

print(img.shape)
# Out:
# (1, 256, 256, 3)

# %%
pred = model.predict(img)
pred_label = tf.argmax(pred, axis=1)
# Map the predicted label to its corresponding name
for key, val in class_map.items():
    if val == pred_label:
        pred_name = key
print(pred_name)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Apple_Yellow
